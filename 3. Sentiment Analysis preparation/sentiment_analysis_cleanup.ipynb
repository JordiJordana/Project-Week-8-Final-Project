# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from nltk.sentiment.util import *
from nltk.corpus import opinion_lexicon

# %%
nyt = pd.read_csv('../2. Data cleaning/nyt.csv')
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.

# %% [markdown]
# With a Lexikon we can label the sentiment of each headline and snippet of text. With Hu and Liu Sentiment Lexicon here a label is set to every headline, so it will be possible to train the model.

# %%
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.

# %% [markdown]
# ## Tokenize data

# %% [markdown]
# In order to create a frequency list of the most used words, words need to be arranged in such a manner that we can get rid of those that convey no meaning.

# %% [markdown]
# In the first place

# %%
def clean_up(s):
    s = re.sub('[^A-Za-z]+', ' ', s)
    return s.lower().strip()

# %%
def tokenize(s):
    s = s.split(' ')
    return s

# %%
def remove_stopwords(sent):
    filtered_words = []
    for word in sent:
        if word not in stopwords.words('english'):
            filtered_words.append(word)
    return filtered_words

# %%
def remove_one_character(sent):
    longer_words = []
    for word in sent:
        if len(word) != 1:
            longer_words.append(word)
    return longer_words

# %%
nyt['headline_token'] = nyt['headline'].apply(clean_up)

# %%
nyt['headline_token'] = nyt['headline_token'].apply(tokenize)

# %%
nyt['headline_token'] = nyt['headline_token'].apply(remove_stopwords)

# %%
nyt['headline_token'] = nyt['headline_token'].apply(remove_one_character)

# %%
nyt.head(10)
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
# 5              2180     Molder of Navajo Youth, Where a Game Is Sacred
# 6              1146   ‘The Affair’ Season 3, Episode 6: Noah Goes Home
# 7               557              Sprint and Mr. Trump’s Fictional Jobs
# 8               784                            America  Becomes a Stan
# 9              1109          Fighting Diabetes, and Leading by Example
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
# 5  In a place of poverty, social ills and fractur...
# 6         As usual, Noah’s story this week was dour.
# 7  The emerging, and dangerous, new form of crony...
# 8              Rule of law is for the little people.
# 9  Eric L. Adams, the Brooklyn borough president,...
#
#                                       headline_token
# 0       [leadership, poised, topple, obama, pillars]
# 1  [fractured, world, tested, hope, young, presid...
# 2                            [little, troublemakers]
# 3             [angela, merkel, russia, next, target]
# 4                             [boots, stranger, bus]
# 5              [molder, navajo, youth, game, sacred]
# 6        [affair, season, episode, noah, goes, home]
# 7               [sprint, mr, trump, fictional, jobs]
# 8                           [america, becomes, stan]
# 9             [fighting, diabetes, leading, example]

# %%
nyt['snippet_token'] = nyt['snippet'].apply(clean_up)

# %%
nyt['snippet_token'] = nyt['snippet_token'].apply(tokenize)

# %%
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
#
#                                       headline_token  \
# 0       [leadership, poised, topple, obama, pillars]
# 1  [fractured, world, tested, hope, young, presid...
# 2                            [little, troublemakers]
# 3             [angela, merkel, russia, next, target]
# 4                             [boots, stranger, bus]
#
#                                        snippet_token
# 0  [the, most, powerful, and, ambitious, republic...
# 1  [a, strategy, that, went, from, a, good, war, ...
# 2    [chuck, deodene, puts, us, in, a, bubbly, mood]
# 3  [with, a, friend, entering, the, white, house,...
# 4  [witnessing, an, act, of, generosity, on, a, r...

# %%
nyt['snippet_token'] = nyt['snippet_token'].apply(remove_stopwords)

# %%
nyt['snippet_token'] = nyt['snippet_token'].apply(remove_one_character)

# %%
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
#
#                                       headline_token  \
# 0       [leadership, poised, topple, obama, pillars]
# 1  [fractured, world, tested, hope, young, presid...
# 2                            [little, troublemakers]
# 3             [angela, merkel, russia, next, target]
# 4                             [boots, stranger, bus]
#
#                                        snippet_token
# 0  [powerful, ambitious, republican, led, congres...
# 1  [strategy, went, good, war, shorthand, afghan,...
# 2           [chuck, deodene, puts, us, bubbly, mood]
# 3  [friend, entering, white, house, vladimir, put...
# 4          [witnessing, act, generosity, rainy, day]

# %%
nyt['tokens'] = nyt['headline_token'] + nyt['snippet_token']
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
#
#                                       headline_token  \
# 0       [leadership, poised, topple, obama, pillars]
# 1  [fractured, world, tested, hope, young, presid...
# 2                            [little, troublemakers]
# 3             [angela, merkel, russia, next, target]
# 4                             [boots, stranger, bus]
#
#                                        snippet_token  \
# 0  [powerful, ambitious, republican, led, congres...
# 1  [strategy, went, good, war, shorthand, afghan,...
# 2           [chuck, deodene, puts, us, bubbly, mood]
# 3  [friend, entering, white, house, vladimir, put...
# 4          [witnessing, act, generosity, rainy, day]
#
#                                               tokens
# 0  [leadership, poised, topple, obama, pillars, p...
# 1  [fractured, world, tested, hope, young, presid...
# 2  [little, troublemakers, chuck, deodene, puts, ...
# 3  [angela, merkel, russia, next, target, friend,...
# 4  [boots, stranger, bus, witnessing, act, genero...

# %%
nyt.drop(columns=['headline_token', 'snippet_token'])
# Out:
#       articleWordCount                                           headline  \
# 0                 1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1                 2836  Fractured World Tested the Hope of a Young Pre...
# 2                  445                               Little Troublemakers
# 3                  864                Angela Merkel, Russia’s Next Target
# 4                  309                      Boots for a Stranger on a Bus
# ...                ...                                                ...
# 7663               785  Dear Match Book: Fiction that Takes Us Back to...
# 7664              1004  This Common Question Reinforces the Gender Pay...
# 7665              1043                                 Anna, Llama and Me
# 7666               659         Gen. Michael Hayden Has One Regret: Russia
# 7667              1155                       There Is Nothin’ Like a Tune
#
#                                                 snippet  \
# 0     The most powerful and ambitious Republican-led...
# 1     A strategy that went from a “good war” to the ...
# 2               Chuck Deodene puts us in a bubbly mood.
# 3     With a friend entering the White House, Vladim...
# 4       Witnessing an act of generosity on a rainy day.
# ...                                                 ...
# 7663  From the bones of 15th-century monarchs, to Ne...
# 7664  Several states and cities have ordered employe...
# 7665  The beginning, middle and end of a picture boo...
# 7666  The former N.S.A. and C.I.A. chief on Trump, S...
# 7667  In “Something Wonderful,” Todd S. Purdum analy...
#
#                                                  tokens
# 0     [leadership, poised, topple, obama, pillars, p...
# 1     [fractured, world, tested, hope, young, presid...
# 2     [little, troublemakers, chuck, deodene, puts, ...
# 3     [angela, merkel, russia, next, target, friend,...
# 4     [boots, stranger, bus, witnessing, act, genero...
# ...                                                 ...
# 7663  [dear, match, book, fiction, takes, us, back, ...
# 7664  [common, question, reinforces, gender, pay, ga...
# 7665  [anna, llama, beginning, middle, end, picture,...
# 7666  [gen, michael, hayden, one, regret, russia, fo...
# 7667  [nothin, like, tune, something, wonderful, tod...
#
# [7668 rows x 4 columns]

# %% [markdown]
# ## Labeling

# %% [markdown]
# With a Lexikon we can label the sentiment of each headline and snippet of text. With Hu and Liu Sentiment Lexicon here a label is set to every headline, so it will be possible to train the model.

# %%
def simple_sentiment(text):
    #tokens = [word.lower() for word in word_tokenize(text)]
    pos_words = 0
    neg_words = 0
    
    for word in text:
        if word in opinion_lexicon.positive():
            pos_words += 1
            #y.append(1) # positive
        elif word in opinion_lexicon.negative():
            neg_words += 1
            #y.append(-1) # negative
        #else:
            #y.append(0) # neutral

    if pos_words > neg_words:
        return 'Positive'
    elif pos_words < neg_words:
        return 'Negative'
    elif pos_words == neg_words:
        return 'Neutral'

# %%
nyt['label_headline'] = nyt['tokens'].apply(simple_sentiment)

nyt.head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-3ba1a9c788c9> in <module>
# ----> 1 nyt['label_headline'] = nyt['headline_token'].apply(simple_sentiment)
#       2
#       3 nyt.head(15)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-111-6d7ae11d9327> in simple_sentiment(text)
#       8             pos_words += 1
#       9             #y.append(1) # positive
# ---> 10         elif word in opinion_lexicon.negative():
#      11             neg_words += 1
#      12             #y.append(-1) # negative
#
# /usr/local/lib/python3.7/site-packages/nltk/collections.py in __contains__(self, value)
#     201     def __contains__(self, value):
#     202         """Return true if this list contains ``value``."""
# --> 203         return bool(self.count(value))
#     204
#     205     def __add__(self, other):
#
# /usr/local/lib/python3.7/site-packages/nltk/collections.py in count(self, value)
#     186     def count(self, value):
#     187         """Return the number of times this list contains ``value``."""
# --> 188         return sum(1 for elt in self if elt == value)
#     189
#     190     def index(self, value, start=None, stop=None):
#
# /usr/local/lib/python3.7/site-packages/nltk/collections.py in <genexpr>(.0)
#     186     def count(self, value):
#     187         """Return the number of times this list contains ``value``."""
# --> 188         return sum(1 for elt in self if elt == value)
#     189
#     190     def index(self, value, start=None, stop=None):
#
# /usr/local/lib/python3.7/site-packages/nltk/corpus/reader/util.py in iterate_from(self, start_tok)
#     304             self._current_toknum = toknum
#     305             self._current_blocknum = block_index
# --> 306             tokens = self.read_block(self._stream)
#     307             assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     308                 'block reader %s() should return list or tuple.'
#
# /usr/local/lib/python3.7/site-packages/nltk/corpus/reader/opinion_lexicon.py in _read_word_block(self, stream)
#     117         words = []
#     118         for i in range(20):  # Read 20 lines at a time.
# --> 119             line = stream.readline()
#     120             if not line:
#     121                 continue
#
# /usr/local/lib/python3.7/site-packages/nltk/data.py in readline(self, size)
#    1214         if self.linebuffer:
#    1215             chars += self.linebuffer.pop()
# -> 1216             self.linebuffer = None
#    1217
#    1218         while True:
#
# KeyboardInterrupt:

# %%
def stem_and_lemmatize(sent):
    stemmed_l = []
    lemmatized_l = []
    for word in sent:
        stemmed_l.append(ps.stem(word))
    for word in stemmed_l:
        lemmatized_l.append(lemmatizer.lemmatize(word))
    return lemmatized_l

# %%
nyt['headline_token'] = nyt['headline_token'].apply(stem_and_lemmatize)
