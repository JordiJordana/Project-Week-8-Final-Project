# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.stem import PorterStemmer
ps = PorterStemmer()
from nltk.sentiment.util import *
from nltk.corpus import opinion_lexicon

# %%
nyt = pd.read_csv('../2. Data cleaning/nyt.csv')
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.

# %% [markdown]
# With a Lexikon we can label the sentiment of each headline and snippet of text. With Hu and Liu Sentiment Lexicon here a label is set to every headline, so it will be possible to train the model.

# %%
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.

# %% [markdown]
# ## Tokenize data

# %% [markdown]
# In order to create a frequency list of the most used words, words need to be arranged in such a manner that we can get rid of those that convey no meaning.

# %% [markdown]
# In the first place

# %%
def clean_up(s):
    s = re.sub('[^A-Za-z]+', ' ', s)
    return s.lower().strip()

# %%
def tokenize(s):
    s = s.split(' ')
    return s

# %%
def remove_stopwords(sent):
    filtered_words = []
    for word in sent:
        if word not in stopwords.words('english'):
            filtered_words.append(word)
    return filtered_words

# %%
def remove_one_character(sent):
    longer_words = []
    for word in sent:
        if len(word) != 1:
            longer_words.append(word)
    return longer_words

# %%
nyt['headline_token'] = nyt['headline'].apply(clean_up)

# %%
nyt['snippet_token'] = nyt['snippet'].apply(clean_up)

# %%
nyt['tokens'] = nyt['headline_token'] + nyt['snippet_token']
nyt.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
#
#                                       headline_token  \
# 0  g o p leadership poised to topple obama s pillars
# 1  fractured world tested the hope of a young pre...
# 2                               little troublemakers
# 3                 angela merkel russia s next target
# 4                      boots for a stranger on a bus
#
#                                        snippet_token  \
# 0  the most powerful and ambitious republican led...
# 1  a strategy that went from a good war to the sh...
# 2             chuck deodene puts us in a bubbly mood
# 3  with a friend entering the white house vladimi...
# 4     witnessing an act of generosity on a rainy day
#
#                                               tokens
# 0  g o p leadership poised to topple obama s pill...
# 1  fractured world tested the hope of a young pre...
# 2  little troublemakerschuck deodene puts us in a...
# 3  angela merkel russia s next targetwith a frien...
# 4  boots for a stranger on a buswitnessing an act...

# %%
nyt.drop(columns=['headline_token', 'snippet_token'], inplace= True)

# %%
nyt['tokens'] = nyt['tokens'].apply(tokenize)

# %%
nyt['tokens'] = nyt['tokens'].apply(remove_stopwords)

# %%
nyt['tokens'] = nyt['tokens'].apply(remove_one_character)

# %%
nyt.head(10)
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
# 5              2180     Molder of Navajo Youth, Where a Game Is Sacred
# 6              1146   ‘The Affair’ Season 3, Episode 6: Noah Goes Home
# 7               557              Sprint and Mr. Trump’s Fictional Jobs
# 8               784                            America  Becomes a Stan
# 9              1109          Fighting Diabetes, and Leading by Example
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
# 5  In a place of poverty, social ills and fractur...
# 6         As usual, Noah’s story this week was dour.
# 7  The emerging, and dangerous, new form of crony...
# 8              Rule of law is for the little people.
# 9  Eric L. Adams, the Brooklyn borough president,...
#
#                                               tokens
# 0  [leadership, poised, topple, obama, pillarsthe...
# 1  [fractured, world, tested, hope, young, presid...
# 2  [little, troublemakerschuck, deodene, puts, us...
# 3  [angela, merkel, russia, next, targetwith, fri...
# 4  [boots, stranger, buswitnessing, act, generosi...
# 5  [molder, navajo, youth, game, sacredin, place,...
# 6  [affair, season, episode, noah, goes, homeas, ...
# 7  [sprint, mr, trump, fictional, jobsthe, emergi...
# 8  [america, becomes, stanrule, law, little, people]
# 9  [fighting, diabetes, leading, exampleeric, ada...

# %% [markdown]
# ## Labeling

# %% [markdown]
# With a Lexikon we can label the sentiment of each headline and snippet of text. With Hu and Liu Sentiment Lexicon here a label is set to every headline, so it will be possible to train the model.

# %%
def simple_sentiment(text):
    
    pos_words = 0
    neg_words = 0
    
    for word in text:
        if word in opinion_lexicon.positive():
            pos_words += 1            
        elif word in opinion_lexicon.negative():
            neg_words += 1
            

    if pos_words > neg_words:
        return 'Positive'
    elif pos_words < neg_words:
        return 'Negative'
    elif pos_words == neg_words:
        return 'Neutral'

# %%
nyt['label_headline'] = nyt['tokens'].apply(simple_sentiment)

nyt.head(15)
# Out:
#     articleWordCount                                           headline  \
# 0               1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1               2836  Fractured World Tested the Hope of a Young Pre...
# 2                445                               Little Troublemakers
# 3                864                Angela Merkel, Russia’s Next Target
# 4                309                      Boots for a Stranger on a Bus
# 5               2180     Molder of Navajo Youth, Where a Game Is Sacred
# 6               1146   ‘The Affair’ Season 3, Episode 6: Noah Goes Home
# 7                557              Sprint and Mr. Trump’s Fictional Jobs
# 8                784                            America  Becomes a Stan
# 9               1109          Fighting Diabetes, and Leading by Example
# 10               533  Chinese Court Says ‘Mr. C’ Was Fired Unjustifi...
# 11               836         Cold Therapy? Maybe Better Save Your Money
# 12              1270  Shunned Stars of Steroid Era Are on Deck for C...
# 13               279    Picking Up a Personal Thread at an Office Party
# 14              3361         Health Reform Could Outlast Repeal Efforts
#
#                                               snippet  \
# 0   The most powerful and ambitious Republican-led...
# 1   A strategy that went from a “good war” to the ...
# 2             Chuck Deodene puts us in a bubbly mood.
# 3   With a friend entering the White House, Vladim...
# 4     Witnessing an act of generosity on a rainy day.
# 5   In a place of poverty, social ills and fractur...
# 6          As usual, Noah’s story this week was dour.
# 7   The emerging, and dangerous, new form of crony...
# 8               Rule of law is for the little people.
# 9   Eric L. Adams, the Brooklyn borough president,...
# 10  The court ordered the company to pay the plain...
# 11  Whole body cryotherapy, which began with elite...
# 12  Some say it is hypocritical to continue reject...
# 13  An acquaintance from work shares something ast...
# 14  A transformation of the delivery of health car...
#
#                                                tokens  \
# 0   [leadership, poised, topple, obama, pillarsthe...
# 1   [fractured, world, tested, hope, young, presid...
# 2   [little, troublemakerschuck, deodene, puts, us...
# 3   [angela, merkel, russia, next, targetwith, fri...
# 4   [boots, stranger, buswitnessing, act, generosi...
# 5   [molder, navajo, youth, game, sacredin, place,...
# 6   [affair, season, episode, noah, goes, homeas, ...
# 7   [sprint, mr, trump, fictional, jobsthe, emergi...
# 8   [america, becomes, stanrule, law, little, people]
# 9   [fighting, diabetes, leading, exampleeric, ada...
# 10  [chinese, court, says, mr, fired, unjustifiabl...
# 11  [cold, therapy, maybe, better, save, moneywhol...
# 12  [shunned, stars, steroid, era, deck, coopersto...
# 13  [picking, personal, thread, office, partyan, a...
# 14  [health, reform, could, outlast, repeal, effor...
#
#                                         snippet_token label_headline
# 0   [powerful, ambitious, republican, led, congres...       Positive
# 1   [strategy, went, good, war, shorthand, afghan,...       Positive
# 2            [chuck, deodene, puts, us, bubbly, mood]        Neutral
# 3   [friend, entering, white, house, vladimir, put...       Negative
# 4           [witnessing, act, generosity, rainy, day]        Neutral
# 5   [place, poverty, social, ills, fractured, fami...        Neutral
# 6                    [usual, noah, story, week, dour]        Neutral
# 7   [emerging, dangerous, new, form, crony, capita...       Negative
# 8                         [rule, law, little, people]        Neutral
# 9   [eric, adams, brooklyn, borough, president, sa...       Positive
# 10  [court, ordered, company, pay, plaintiff, iden...        Neutral
# 11  [whole, body, cryotherapy, began, elite, athle...       Positive
# 12  [say, hypocritical, continue, rejecting, forme...       Negative
# 13  [acquaintance, work, shares, something, astoun...       Positive
# 14  [transformation, delivery, health, care, may, ...       Positive

# %%
nyt_clean = nyt.drop(columns=['snippet_token'])
nyt_clean.head()
# Out:
#    articleWordCount                                           headline  \
# 0              1324   G.O.P. Leadership Poised to Topple Obama’s Pi...
# 1              2836  Fractured World Tested the Hope of a Young Pre...
# 2               445                               Little Troublemakers
# 3               864                Angela Merkel, Russia’s Next Target
# 4               309                      Boots for a Stranger on a Bus
#
#                                              snippet  \
# 0  The most powerful and ambitious Republican-led...
# 1  A strategy that went from a “good war” to the ...
# 2            Chuck Deodene puts us in a bubbly mood.
# 3  With a friend entering the White House, Vladim...
# 4    Witnessing an act of generosity on a rainy day.
#
#                                               tokens label_headline
# 0  [leadership, poised, topple, obama, pillarsthe...       Positive
# 1  [fractured, world, tested, hope, young, presid...       Positive
# 2  [little, troublemakerschuck, deodene, puts, us...        Neutral
# 3  [angela, merkel, russia, next, targetwith, fri...       Negative
# 4  [boots, stranger, buswitnessing, act, generosi...        Neutral

# %%
type(nyt.tokens)
# Out:
# pandas.core.series.Series

# %%
def row_strip (ser):
    for row in ser:
        row = row.rstrip()
        return(row)
    
all_words = nyt.tokens.apply(row_strip)

# %%
list_of_words = {}

for word in all_words:
    if word not in list_of_words.keys():
        list_of_words[word] = 1
    else:
        list_of_words[word] += 1

# %%
list_of_words
# Out:
# {'leadership': 2,
#  'fractured': 1,
#  'little': 19,
#  'angela': 3,
#  'boots': 1,
#  'molder': 1,
#  'affair': 5,
#  'sprint': 1,
#  'america': 17,
#  'fighting': 10,
#  'chinese': 8,
#  'cold': 3,
#  'shunned': 1,
#  'picking': 3,
#  'health': 15,
#  'mr': 42,
#  'house': 20,
#  'right': 12,
#  'lessons': 5,
#  'talkmichael': 1,
#  'winter': 5,
#  'snapchat': 1,
#  'power': 8,
#  'fraud': 1,
#  'new': 146,
#  'year': 10,
#  'questions': 61,
#  'predictions': 1,
#  'workout': 1,
#  'pregnancy': 9,
#  'fox': 6,
#  'wishful': 1,
#  'arms': 1,
#  'leicester': 2,
#  'evaluate': 1,
#  'second': 4,
#  'major': 4,
#  'variety': 35,
#  'russians': 4,
#  'starve': 1,
#  'crime': 4,
#  'white': 22,
#  'war': 8,
#  'yes': 10,
#  'forgotten': 1,
#  'future': 2,
#  'downsizing': 2,
#  'bond': 1,
#  'la': 4,
#  'fury': 4,
#  'failure': 2,
#  'star': 9,
#  'grim': 2,
#  'secret': 5,
#  'hiding': 1,
#  'assange': 1,
#  'strikes': 1,
#  'turn': 3,
#  'beast': 2,
#  'deficits': 1,
#  'humanism': 1,
#  'erasing': 1,
#  'michelle': 1,
#  'age': 4,
#  'home': 8,
#  'dabbing': 1,
#  'opponents': 1,
#  'qing': 1,
#  'friday': 20,
#  'teaching': 84,
#  'grabbing': 1,
#  'japanese': 1,
#  'trump': 253,
#  'assembly': 1,
#  'putin': 8,
#  'rumors': 2,
#  'jobs': 3,
#  'agreement': 1,
#  'world': 13,
#  'dangers': 2,
#  'giving': 5,
#  'instagram': 1,
#  'middle': 2,
#  'swan': 1,
#  'every': 3,
#  'inauguration': 1,
#  'single': 1,
#  'body': 3,
#  'fateful': 1,
#  'social': 8,
#  'feed': 1,
#  'predict': 1,
#  'motto': 1,
#  'chocolate': 2,
#  'paraguay': 1,
#  'packers': 2,
#  'cocktail': 1,
#  'bipartisan': 2,
#  'first': 15,
#  'strangers': 3,
#  'skunks': 1,
#  'might': 2,
#  'department': 3,
#  'numbers': 1,
#  'really': 4,
#  'watch': 6,
#  'homelessness': 1,
#  'going': 34,
#  'curbing': 1,
#  'emotion': 1,
#  'playoff': 1,
#  'slower': 1,
#  'believe': 2,
#  'son': 3,
#  'women': 21,
#  'soldiers': 2,
#  'left': 5,
#  'cuomo': 7,
#  'vw': 1,
#  'disc': 1,
#  'clemson': 1,
#  'dancers': 1,
#  'bannon': 7,
#  'hack': 1,
#  'republican': 14,
#  'fight': 4,
#  'big': 23,
#  'fifa': 1,
#  'trash': 1,
#  'remember': 2,
#  'cover': 2,
#  'listhe': 1,
#  'streep': 1,
#  'weekly': 8,
#  'title': 1,
#  'prisons': 2,
#  'said': 1,
#  'rye': 1,
#  'flavor': 1,
#  'seven': 1,
#  'gifts': 1,
#  'get': 15,
#  'pillar': 1,
#  'knotpeter': 1,
#  'offbeat': 2,
#  'online': 1,
#  'kellyanne': 1,
#  'life': 16,
#  'fix': 4,
#  'sue': 1,
#  'physician': 1,
#  'good': 34,
#  'us': 1,
#  'mindful': 17,
#  'weekend': 2,
#  'economists': 1,
#  'britain': 15,
#  'partisanship': 3,
#  'family': 9,
#  'talking': 2,
#  'difference': 1,
#  'door': 1,
#  'looking': 10,
#  'former': 11,
#  'cancer': 4,
#  'text': 4,
#  'mind': 8,
#  'glare': 1,
#  'finding': 11,
#  'coming': 5,
#  'stock': 3,
#  'headwhat': 1,
#  'anti': 4,
#  'party': 4,
#  'rural': 2,
#  'china': 21,
#  'sketch': 1,
#  'seeing': 3,
#  'senate': 5,
#  'back': 9,
#  'modern': 4,
#  'ode': 2,
#  'bold': 3,
#  'old': 10,
#  'day': 6,
#  'able': 3,
#  'things': 3,
#  'device': 1,
#  'silicon': 6,
#  'website': 1,
#  'chance': 3,
#  'charts': 1,
#  'tantrum': 1,
#  'open': 4,
#  'personal': 1,
#  'vera': 1,
#  'hands': 4,
#  'necessity': 2,
#  'fascinating': 1,
#  'turkey': 2,
#  'michael': 1,
#  'ex': 6,
#  'expecting': 1,
#  'bombafter': 1,
#  'frightful': 1,
#  'fitness': 3,
#  'probably': 3,
#  'republicans': 17,
#  'winners': 3,
#  'men': 7,
#  'italy': 3,
#  'possible': 1,
#  'serve': 2,
#  'could': 4,
#  'circling': 3,
#  'choosing': 3,
#  'fair': 2,
#  'american': 9,
#  'encourage': 1,
#  'washington': 5,
#  'nominees': 2,
#  'parents': 9,
#  'student': 11,
#  'high': 10,
#  'patients': 1,
#  'building': 7,
#  'theme': 1,
#  'reporter': 2,
#  'sound': 3,
#  'obama': 12,
#  'eat': 15,
#  'reds': 1,
#  'comey': 4,
#  'money': 7,
#  'ends': 1,
#  'toughness': 1,
#  'updated': 1,
#  'mayor': 7,
#  'donald': 24,
#  'markets': 4,
#  'better': 12,
#  'sudden': 2,
#  'celebrated': 1,
#  'leda': 1,
#  'think': 15,
#  'issuereaders': 1,
#  'lost': 6,
#  'fragile': 1,
#  'neighbor': 2,
#  'wells': 2,
#  'predatory': 1,
#  'raw': 3,
#  'excessive': 1,
#  'one': 26,
#  'cauliflower': 1,
#  'post': 1,
#  'robot': 1,
#  'cell': 2,
#  'ben': 2,
#  'shopping': 4,
#  'mother': 6,
#  'choice': 2,
#  'without': 4,
#  'trumpian': 1,
#  'optimism': 1,
#  'freaking': 1,
#  'racial': 1,
#  'black': 15,
#  'says': 5,
#  'grammar': 1,
#  'dropped': 1,
#  'mere': 1,
#  'tax': 14,
#  'completelyjohn': 1,
#  'rolling': 2,
#  'homeland': 12,
#  'daughter': 3,
#  'tennis': 1,
#  'due': 1,
#  'celebratesince': 1,
#  'children': 7,
#  'reading': 3,
#  'banned': 1,
#  'deliberate': 1,
#  'de': 5,
#  'job': 2,
#  'getting': 6,
#  'wary': 1,
#  'puppet': 1,
#  'beloved': 1,
#  'british': 3,
#  'taking': 13,
#  'earth': 2,
#  'thomas': 1,
#  'lord': 1,
#  'ambassadors': 1,
#  'growing': 3,
#  'mail': 1,
#  'wish': 3,
#  'role': 2,
#  'hall': 1,
#  'tropical': 1,
#  'call': 8,
#  'watching': 4,
#  'invisible': 1,
#  'sexes': 1,
#  'pressure': 6,
#  'marching': 2,
#  'grass': 1,
#  'chef': 4,
#  'slurping': 1,
#  'favor': 1,
#  'devos': 2,
#  'rattle': 1,
#  'dynamic': 3,
#  'sneakersare': 1,
#  'injecting': 1,
#  'retweeting': 1,
#  'non': 1,
#  'diverse': 1,
#  'told': 1,
#  'arm': 2,
#  'would': 14,
#  'disenrolledfour': 1,
#  'times': 9,
#  'hunting': 1,
#  'running': 4,
#  'amid': 3,
#  'third': 1,
#  'speaking': 2,
#  'farewell': 1,
#  'anthony': 2,
#  'fake': 7,
#  'suit': 3,
#  'liability': 1,
#  'prospero': 1,
#  'hitler': 2,
#  'supreme': 11,
#  'missing': 8,
#  'bernard': 2,
#  'alarmeddonald': 1,
#  'got': 2,
#  'vladimir': 1,
#  'hot': 8,
#  'know': 8,
#  'grandmother': 3,
#  'carla': 1,
#  'national': 4,
#  'let': 17,
#  'safety': 8,
#  'ways': 4,
#  'evaluating': 2,
#  'road': 3,
#  'issues': 1,
#  'ethical': 1,
#  'journalism': 2,
#  'end': 15,
#  'losing': 7,
#  'delivering': 1,
#  'el': 3,
#  'marooned': 1,
#  'movie': 3,
#  'spontaneous': 1,
#  'ancient': 4,
#  'marginalized': 2,
#  'internal': 1,
#  'optimistic': 1,
#  'achieving': 1,
#  'avoiding': 2,
#  'confessions': 1,
#  'global': 7,
#  'hopes': 3,
#  'detained': 1,
#  'guard': 2,
#  'stood': 1,
#  'retirement': 2,
#  'federal': 2,
#  'story': 5,
#  'trumpism': 4,
#  'president': 39,
#  'ya': 1,
#  'exactly': 1,
#  'baseball': 6,
#  'next': 8,
#  'executive': 1,
#  'may': 7,
#  'beijing': 4,
#  'tempting': 1,
#  'mishmashdan': 1,
#  'defiant': 1,
#  'different': 3,
#  'marchers': 1,
#  'takes': 8,
#  'rachel': 2,
#  'always': 4,
#  'parent': 1,
#  'dissidents': 1,
#  'discovering': 1,
#  'buzzfeed': 1,
#  'administration': 5,
#  'learned': 3,
#  'tribe': 1,
#  'exercise': 5,
#  'dwellings': 1,
#  'phone': 2,
#  'cities': 2,
#  'cloud': 1,
#  'police': 6,
#  'upending': 3,
#  'excellence': 1,
#  'barron': 1,
#  'quandary': 2,
#  'murder': 2,
#  'birth': 4,
#  'dads': 1,
#  'meeting': 6,
#  'masterpiece': 1,
#  'love': 17,
#  'mandatory': 1,
#  'quang': 1,
#  'marchthe': 1,
#  'brenda': 1,
#  'items': 1,
#  'alexa': 2,
#  'lying': 1,
#  'french': 9,
#  'oscar': 2,
#  'many': 9,
#  'river': 1,
#  'banal': 1,
#  'silence': 3,
#  'gilded': 1,
#  'burn': 2,
#  'reimagining': 1,
#  'wrong': 7,
#  'court': 4,
#  'trial': 3,
#  'care': 1,
#  'people': 5,
#  'riding': 1,
#  'pipelines': 1,
#  'nafta': 1,
#  'mexican': 2,
#  'mary': 1,
#  'orbital': 1,
#  'ordered': 1,
#  'dow': 2,
#  'chefs': 1,
#  'canada': 7,
#  'take': 9,
#  'sympathy': 1,
#  'tensions': 2,
#  'frozen': 2,
#  'lie': 2,
#  'intellectual': 2,
#  'pence': 4,
#  'save': 6,
#  'radical': 3,
#  'pedialytea': 1,
#  'crimes': 1,
#  'favorite': 4,
#  'art': 10,
#  'news': 2,
#  'alternative': 5,
#  'presidential': 4,
#  'illegal': 1,
#  'mining': 1,
#  'subtlety': 1,
#  'ideas': 2,
#  'young': 7,
#  'scenes': 1,
#  'must': 4,
#  'conservatives': 2,
#  'interpret': 1,
#  'late': 5,
#  'mounds': 1,
#  'snubbed': 2,
#  'tons': 1,
#  'playing': 2,
#  'noir': 1,
#  'exploring': 1,
#  'lunar': 1,
#  'politics': 4,
#  'making': 10,
#  'speak': 4,
#  'protest': 2,
#  'surviving': 1,
#  'sick': 2,
#  'mutinies': 1,
#  'view': 1,
#  'searching': 2,
#  'thoughts': 2,
#  'hugs': 2,
#  'closing': 3,
#  'buying': 2,
#  'religious': 2,
#  'residents': 1,
#  'shhh': 1,
#  'sun': 1,
#  'three': 9,
#  'admiration': 1,
#  'caps': 1,
#  'broken': 2,
#  'soccer': 1,
#  'private': 1,
#  'mexico': 1,
#  'gesture': 1,
#  'voter': 2,
#  'judge': 9,
#  'mom': 3,
#  'fog': 1,
#  'sisterly': 1,
#  'wild': 2,
#  'live': 5,
#  'hit': 3,
#  'mastectomy': 1,
#  'decadent': 1,
#  'certain': 2,
#  'sorry': 3,
#  'famous': 2,
#  'analyzing': 1,
#  'recognition': 1,
#  'reactions': 1,
#  'blue': 4,
#  'voice': 2,
#  'anybody': 1,
#  'yearning': 1,
#  'invitation': 1,
#  'madeira': 1,
#  'ferocious': 1,
#  'pick': 4,
#  'ten': 1,
#  'chaos': 4,
#  'iran': 2,
#  'homework': 2,
#  'raising': 4,
#  'protestinghave': 1,
#  'wedded': 2,
#  'make': 9,
#  'combat': 3,
#  'scrutinizing': 1,
#  'negative': 1,
#  'seventh': 1,
#  'families': 1,
#  'signing': 1,
#  'spin': 1,
#  'learning': 6,
#  'dissent': 1,
#  'terrified': 1,
#  'wash': 1,
#  'neil': 1,
#  'game': 4,
#  'den': 1,
#  'healthy': 2,
#  'dear': 10,
#  'jared': 3,
#  'threat': 3,
#  'joe': 2,
#  'mysteries': 1,
#  'co': 5,
#  'shortest': 1,
#  'conservatism': 1,
#  'immigrant': 2,
#  'paris': 2,
#  'celebrating': 3,
#  'falwell': 1,
#  'hormone': 1,
#  'vs': 2,
#  'sinister': 1,
#  'trail': 2,
#  'super': 5,
#  'fruit': 2,
#  'apology': 1,
#  'stand': 4,
#  'swimmer': 1,
#  'peculiar': 1,
#  'video': 3,
#  'change': 2,
#  'busy': 3,
#  'dollar': 2,
#  'hardware': 1,
#  'cajun': 1,
#  'refugee': 2,
#  'brain': 3,
#  'arguing': 1,
#  'space': 3,
#  'australia': 3,
#  'heart': 12,
#  'pregnant': 1,
#  'sideswiped': 1,
#  'needed': 1,
#  'anarchists': 1,
#  'something': 5,
#  'tattooshow': 1,
#  'democrats': 23,
#  'tyrant': 1,
#  'return': 2,
#  'best': 9,
#  'bonus': 5,
#  'great': 15,
#  'california': 6,
#  'opposition': 2,
#  'diversity': 1,
#  'gillibrand': 1,
#  'run': 1,
#  'vote': 1,
#  'college': 4,
#  'gnocchi': 1,
#  'cupcake': 1,
#  'craftbar': 1,
#  'drop': 1,
#  'defense': 2,
#  'smothers': 1,
#  'tagliabue': 1,
#  'poison': 2,
#  'revisiting': 2,
#  'wethe': 1,
#  'mefor': 1,
#  'free': 3,
#  'readying': 1,
#  'chelsea': 1,
#  'excusing': 1,
#  'grading': 1,
#  'james': 7,
#  'common': 4,
#  'nominee': 1,
#  'epic': 2,
#  'finger': 1,
#  'familiar': 3,
#  'rethinking': 1,
#  'lesson': 4,
#  'springtime': 2,
#  'afraid': 1,
#  'prepared': 1,
#  'full': 3,
#  'soothing': 1,
#  'child': 5,
#  'aging': 2,
#  'meatloaf': 1,
#  'brewers': 1,
#  'justice': 9,
#  'slave': 1,
#  'cheese': 1,
#  'god': 6,
#  'well': 5,
#  'short': 1,
#  'queen': 4,
#  'mercy': 1,
#  'vatican': 1,
#  'pro': 2,
#  'labor': 4,
#  'fallows': 1,
#  'tom': 1,
#  'close': 3,
#  'jimmy': 10,
#  'forces': 2,
#  'keepers': 1,
#  'using': 4,
#  'debate': 3,
#  'details': 2,
#  'seemed': 1,
#  'sweet': 4,
#  'sugar': 3,
#  'meat': 1,
#  'stephen': 13,
#  'showman': 1,
#  'go': 9,
#  'comforts': 1,
#  'judges': 4,
#  'accidental': 1,
#  'yemenis': 1,
#  'opening': 3,
#  'spendingdo': 1,
#  'obamacare': 10,
#  'preparing': 1,
#  'connecting': 3,
#  'conservative': 2,
#  'lab': 1,
#  'preacher': 1,
#  'willie': 1,
#  'teenager': 3,
#  'fong': 1,
#  'ready': 4,
#  'problem': 2,
#  'ghoulsa': 1,
#  'quiet': 7,
#  'outsiders': 2,
#  'monumental': 1,
#  'met': 5,
#  'lady': 1,
#  'elizabeth': 1,
#  'almost': 1,
#  'integration': 3,
#  'recordings': 1,
#  'table': 2,
#  'immortality': 1,
#  'typical': 1,
#  'lettuce': 1,
#  'speed': 2,
#  'vocal': 1,
#  'start': 5,
#  'thai': 1,
#  'ivanka': 4,
#  'john': 6,
#  'several': 1,
#  'postwar': 2,
#  'wide': 1,
#  'stepping': 2,
#  'consumer': 1,
#  'oakley': 1,
#  'sexiest': 1,
#  'te': 1,
#  'fire': 7,
#  'gift': 2,
#  'bad': 8,
#  'preserving': 1,
#  'much': 11,
#  'bodega': 2,
#  'hard': 8,
#  'political': 6,
#  'doctors': 6,
#  'reaction': 3,
#  'welcome': 3,
#  'cars': 1,
#  'walking': 18,
#  'fooled': 1,
#  'sauce': 1,
#  'par': 2,
#  'cool': 2,
#  'sexy': 1,
#  'knicks': 2,
#  'billions': 17,
#  'campus': 1,
#  'fixing': 3,
#  'garden': 1,
#  'foreign': 2,
#  'footing': 1,
#  'regulation': 1,
#  'civil': 3,
#  'led': 2,
#  'kushner': 5,
#  'outonly': 1,
#  'husbands': 1,
#  'presidency': 1,
#  'since': 1,
#  'splitslynn': 1,
#  'adele': 1,
#  'slide': 1,
#  'migrating': 1,
#  'two': 17,
#  'hairy': 1,
#  'find': 2,
#  'ignorance': 1,
#  'unraveling': 1,
#  'puzzling': 1,
#  'bariatric': 1,
#  'teen': 1,
#  'americans': 20,
#  'snow': 3,
#  'texts': 1,
#  'angry': 3,
#  'almond': 1,
#  'uconn': 1,
#  'wine': 2,
#  'small': 4,
#  'abc': 1,
#  'dam': 1,
#  'entertainment': 1,
#  'achin': 1,
#  'facing': 3,
#  'canal': 1,
#  'archenemy': 1,
#  'whistling': 1,
#  'valentine': 3,
#  'struggle': 1,
#  'israel': 5,
#  'rules': 4,
#  'bonhoeffer': 1,
#  'even': 4,
#  'athletes': 1,
#  'carnival': 1,
#  'humanwhen': 1,
#  'say': 2,
#  'youngest': 1,
#  'settler': 1,
#  'scalp': 1,
#  'bringing': 6,
#  'years': 11,
#  'risingthe': 1,
#  'flames': 1,
#  'eroding': 1,
#  'alonewhat': 1,
#  'tug': 1,
#  'crossword': 3,
#  'confusion': 1,
#  'indians': 2,
#  'nadal': 1,
#  'like': 13,
#  'winning': 1,
#  'wife': 2,
#  'compost': 1,
#  'marilyn': 1,
#  'press': 2,
#  'grocers': 1,
#  'months': 1,
#  'distracted': 1,
#  'drip': 1,
#  'bechdel': 1,
#  'investors': 2,
#  'congress': 7,
#  'sing': 2,
#  'everyman': 1,
#  'fixed': 1,
#  'legion': 8,
#  'solving': 1,
#  'advice': 2,
#  'kinds': 1,
#  'praise': 5,
#  'meager': 2,
#  'ultimate': 2,
#  'maintenance': 1,
#  'date': 2,
#  'youtube': 4,
#  'immigrants': 3,
#  'korean': 1,
#  'blurring': 1,
#  'riot': 1,
#  'boy': 3,
#  'redirecting': 1,
#  'cabs': 1,
#  'dystopia': 1,
#  'often': 1,
#  'fears': 3,
#  'hair': 2,
#  'government': 3,
#  'diagnosing': 1,
#  'bring': 2,
#  'singing': 2,
#  'conversations': 1,
#  'resistance': 1,
#  'trespassing': 1,
#  'crunch': 1,
#  'slam': 1,
#  'skinnier': 1,
#  'constraints': 1,
#  'night': 3,
#  'name': 2,
#  'finance': 2,
#  'alone': 2,
#  'shy': 1,
#  'grunt': 1,
#  'bright': 3,
#  'hum': 1,
#  'cheesecake': 1,
#  'putindon': 1,
#  'breaking': 2,
#  'beltway': 1,
#  'unnamed': 1,
#  'movies': 1,
#  'trapped': 2,
#  'tent': 1,
#  'uh': 1,
#  'numbera': 1,
#  'holiday': 1,
#  'overheard': 1,
#  'ryancare': 1,
#  'older': 4,
#  'irresistible': 1,
#  'economic': 3,
#  'harry': 1,
#  'expect': 3,
#  'worst': 3,
#  'military': 4,
#  'runaway': 1,
#  'striking': 1,
#  'state': 11,
#  'robots': 3,
#  'ambitious': 1,
#  'century': 2,
#  'move': 4,
#  'oscarssoorangefrank': 1,
#  'russifying': 1,
#  'town': 3,
#  'protesters': 1,
#  'language': 1,
#  'eleven': 2,
#  'ever': 7,
#  'scammers': 2,
#  'waldorf': 1,
#  'culinary': 2,
#  'downfall': 1,
#  'mardi': 1,
#  'hear': 2,
#  'milo': 1,
#  'driving': 4,
#  'deportation': 1,
#  'quite': 3,
#  'chess': 1,
#  'doomed': 1,
#  'meaning': 1,
#  'standing': 2,
#  'meet': 4,
#  'communist': 1,
#  'subway': 6,
#  'case': 10,
#  'therapist': 1,
#  'relief': 1,
#  'shadowy': 1,
#  'retake': 1,
#  'chief': 8,
#  'sleep': 2,
#  'soda': 2,
#  'uber': 6,
#  'bitter': 1,
#  'napoleon': 1,
#  'death': 6,
#  'humans': 2,
#  'letting': 5,
#  'lennon': 1,
#  'retrainingmany': 1,
#  'purpose': 2,
#  'automationthe': 1,
#  'divisions': 1,
#  'democracy': 7,
#  'dismal': 2,
#  'transgender': 3,
#  'tables': 1,
#  'alarmed': 1,
#  'warming': 2,
#  'cute': 1,
#  'guess': 3,
#  'teenage': 1,
#  'revolution': 1,
#  'mugged': 1,
#  'track': 3,
#  'darling': 1,
#  'living': 9,
#  'rising': 5,
#  'long': 10,
#  'north': 12,
#  'unmaking': 1,
#  'aid': 1,
#  'actually': 3,
#  'disappearing': 1,
#  'nothing': 2,
#  'croque': 1,
#  'history': 1,
#  'crossing': 2,
#  'farming': 1,
#  'shadows': 2,
#  'clear': 1,
#  'characters': 1,
#  'lyndon': 2,
#  'designs': 1,
#  'calling': 3,
#  'want': 11,
#  'lakers': 1,
#  'agents': 1,
#  'costs': 1,
#  'time': 13,
#  'steve': 2,
#  'ask': 7,
#  'mixed': 3,
#  'real': 15,
#  'season': 13,
#  'industry': 2,
#  'ones': 1,
#  'widespread': 1,
#  'lift': 1,
#  'local': 2,
#  'forger': 1,
#  'uses': 1,
#  'immigration': 3,
#  'reclusive': 1,
#  'happens': 3,
#  'competitive': 2,
#  'budget': 2,
#  'studying': 1,
#  'dueling': 1,
#  'compliment': 1,
#  'battered': 1,
#  'honest': 1,
#  'virtual': 2,
#  'today': 5,
#  'blank': 1,
#  'hole': 1,
#  'playboy': 1,
#  'system': 1,
#  'memorable': 1,
#  'click': 2,
#  'ordering': 1,
#  'vitamins': 1,
#  'sharp': 2,
#  'citing': 2,
#  'matt': 1,
#  'towns': 1,
#  'showing': 1,
#  'whatever': 2,
#  'net': 1,
#  'stressed': 1,
#  ...}

# %%
all_words = nltk.FreqDist(all_words)

# %%
all_words
# Out:
# FreqDist({'trump': 253, 'new': 146, 'teaching': 84, 'questions': 61, 'mr': 42, 'president': 39, 'variety': 35, 'going': 34, 'good': 34, 'one': 26, ...})

# %%
most_common = all_words.most_common(500)

# %%
most_common
# Out:
# [('trump', 253),
#  ('new', 146),
#  ('teaching', 84),
#  ('questions', 61),
#  ('mr', 42),
#  ('president', 39),
#  ('variety', 35),
#  ('going', 34),
#  ('good', 34),
#  ('one', 26)]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-9640db3945de> in <module>
# ----> 1 nyt_clean
#
# NameError: name 'nyt_clean' is not defined

# %%
nyt_clean.to_csv('./sentiment_prepared.csv')
